# %% [markdown]
# # Line, Pie and Bar Charts
#
# Line Chart: to show changes over time
# Bar Chart: to show changes by category
# Pie Chart: to show categorical data as proportions of whole
#
# There are 2 methods to build plots in Python. One is Functional(calling plot function on variable or more variables) and other is Object-Oriented where you first build a blank object and then plot a figure on it.
#
# Most Popular Data Visualization Libraries are Seaborn and matplotlib.

# %%
! pip install Seaborn
# Out:
# ...
#     100% |████████████████████████████████| 163kB 504kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 4.4MB 239kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 16.2MB 75kB/s eta 0:00:011
# ...
#     100% |████████████████████████████████| 12.8MB 97kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 15.0MB 82kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 194kB 2.3MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 3.8MB/s ta 0:00:011
# ...
#   Using cached six-1.10.0-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 491kB 1.2MB/s ta 0:00:011
# ...
#   Using cached pyparsing-2.2.0-py2.py3-none-any.whl
# ...
# done
# done
# done
# ...

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
 # this lets plots to be plotted in same window
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4 # 5 inch cross 4 inch figures
sb.set_style('whitegrid')

# %% [markdown]
# ## Line Chart

# %%
# Create sample dataset
x = range(1,10)
y = [1,2,5,8,3,6,2,0,9]
# Plot data using matplotlib
plt.plot(x,y)

# %%
address = '/Users/dhanashreepokale/Downloads/Ex_Files_Python_Data_Science_EssT/Exercise Files/Ch01/01_05/mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
mpg = cars['mpg']

# %%
# ploting using pandas
mpg.plot()

# %%
# Plotting multiple variables
# Create subset of the dataset
df = cars[['cyl','mpg','wt']]

# %%
df.plot()

# %% [markdown]
# ## Bar Plots

# %%
plt.bar(x,y)
# Out:
# <Container object of 9 artists>

# %%
# using pandas for bar chart
mpg.plot(kind='bar')

# %%
mpg.plot(kind='barh')

# %% [markdown]
# ## Pie Chart

# %%
x= [1,2,4,3,0,5]
plt.pie(x)
plt.show()

# %%
# Saving plots as jpeg
plt.savefig('PieChart.jpeg')
plt.show()
